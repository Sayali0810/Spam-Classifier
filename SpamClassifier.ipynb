# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv',
                 sep='\t', names=['label', 'message'])

# %%
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# Load dataset
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv',
                 sep='\t', names=['label', 'message'])

# Convert labels
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# Split
X_train, X_test, y_train, y_test = train_test_split(df['message'], df['label'], test_size=0.2)

# Vectorize
vectorizer = TfidfVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)

# Train model
model = MultinomialNB()
model.fit(X_train_vec, y_train)

# Save model + vectorizer
pickle.dump(model, open('model.pkl', 'wb'))
pickle.dump(vectorizer, open('vectorizer.pkl', 'wb'))

print("Model trained and saved!")
# Out:
# Model trained and saved!

# %%
# !python train.py
# Out:
# python: can't open file 'C:\\Users\\sayal\\train.py': [Errno 2] No such file or directory

# %%
import streamlit as st
import pickle

# Load model and vectorizer
model = pickle.load(open('model.pkl', 'rb'))
vectorizer = pickle.load(open('vectorizer.pkl', 'rb'))

# Page config
st.set_page_config(page_title="Spam Classifier", page_icon="📩")

# Title
st.title("📩 Spam Message Classifier")
st.write("Enter a message and check if it's Spam or Not")

# Input box
message = st.text_area("Enter your message:")

if st.button("Predict"):
    if message.strip() == "":
        st.warning("Please enter a message")
    else:
        # Transform input
        data = vectorizer.transform([message])
        
        # Predict
        prediction = model.predict(data)[0]
        probability = model.predict_proba(data)[0][1]

        # Output
        if prediction == 1:
            st.error(f"🚨 Spam Message (Confidence: {probability:.2f})")
        else:
            st.success(f"✅ Not Spam (Confidence: {1 - probability:.2f})")
# Out:
# 2026-03-17 23:10:16.792 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:16.793 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.959
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\sayal\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-17 23:10:17.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.968 Session state does not function when running a script without `streamlit run`
# 2026-03-17 23:10:17.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 23:10:17.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
